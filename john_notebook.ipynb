# %%
# ignore warnings
import warnings
warnings.filterwarnings("ignore")
# Wrangling
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
# Statistical Tests
import scipy.stats as stats
from scipy.stats import norm
# Visualizing
import matplotlib.pyplot as plt
from matplotlib import cm
import matplotlib.dates as dates
import seaborn as sns
from sklearn.model_selection import learning_curve
import datetime
pd.options.display.float_format = '{:20,.2f}'.format
import env

# %%
import wrangle

from wrangle import get_zillow_data

# %%
df = get_zillow_data()

# %%
df.head()
# Out:
#    typeconstructiontypeid          storytypeid  heatingorsystemtypeid  \
# 0                     nan                  nan                   2.00
# 1                     nan                  nan                   2.00
# 2                     nan                  nan                   2.00
# 3                     nan                  nan                   2.00
# 4                     nan                  nan                   2.00
#
#    buildingclasstypeid  architecturalstyletypeid  airconditioningtypeid  \
# 0                  nan                       nan                    nan
# 1                  nan                       nan                   1.00
# 2                  nan                       nan                   1.00
# 3                  nan                       nan                    nan
# 4                  nan                       nan                    nan
#
#    parcelid       id         basementsqft          bathroomcnt  ...  \
# 0  10711855  1087254                  nan                 2.00  ...
# 1  10711877  1072280                  nan                 2.00  ...
# 2  10711888  1340933                  nan                 2.00  ...
# 3  10711910  1878109                  nan                 2.00  ...
# 4  10711923  2190858                  nan                 2.00  ...
#
#     taxdelinquencyyear   censustractandblock             logerror  \
# 0                  nan 60,371,132,321,007.00                -0.01
# 1                  nan 60,371,132,321,007.00                 0.02
# 2                  nan 60,371,132,321,007.00                 0.08
# 3                  nan 60,371,132,321,008.00                -0.04
# 4                  nan 60,371,132,321,008.00                -0.01
#
#    transactiondate  airconditioningdesc  architecturalstyledesc  \
# 0       2017-07-07                 None                    None
# 1       2017-08-29              Central                    None
# 2       2017-04-04              Central                    None
# 3       2017-03-17                 None                    None
# 4       2017-03-24                 None                    None
#
#    buildingclassdesc  heatingorsystemdesc  storydesc  typeconstructiondesc
# 0               None              Central       None                  None
# 1               None              Central       None                  None
# 2               None              Central       None                  None
# 3               None              Central       None                  None
# 4               None              Central       None                  None
#
# [5 rows x 67 columns]

# %%
df.shape
# Out:
# (77413, 67)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77413 entries, 0 to 77412
# Data columns (total 67 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   typeconstructiontypeid        222 non-null    float64
#  1   storytypeid                   50 non-null     float64
#  2   heatingorsystemtypeid         49439 non-null  float64
#  3   buildingclasstypeid           15 non-null     float64
#  4   architecturalstyletypeid      206 non-null    float64
#  5   airconditioningtypeid         24953 non-null  float64
#  6   parcelid                      77413 non-null  int64
#  7   id                            77413 non-null  int64
#  8   basementsqft                  50 non-null     float64
#  9   bathroomcnt                   77380 non-null  float64
#  10  bedroomcnt                    77380 non-null  float64
#  11  buildingqualitytypeid         49671 non-null  float64
#  12  calculatedbathnbr             76771 non-null  float64
#  13  decktypeid                    614 non-null    float64
#  14  finishedfloor1squarefeet      6023 non-null   float64
#  15  calculatedfinishedsquarefeet  77184 non-null  float64
#  16  finishedsquarefeet12          73748 non-null  float64
#  17  finishedsquarefeet13          41 non-null     float64
#  18  finishedsquarefeet15          3009 non-null   float64
#  19  finishedsquarefeet50          6023 non-null   float64
#  20  finishedsquarefeet6           386 non-null    float64
#  21  fips                          77380 non-null  float64
#  22  fireplacecnt                  8276 non-null   float64
#  23  fullbathcnt                   76771 non-null  float64
#  24  garagecarcnt                  25474 non-null  float64
#  25  garagetotalsqft               25474 non-null  float64
#  26  hashottuborspa                1538 non-null   float64
#  27  latitude                      77380 non-null  float64
#  28  longitude                     77380 non-null  float64
#  29  lotsizesquarefeet             69141 non-null  float64
#  30  poolcnt                       16137 non-null  float64
#  31  poolsizesum                   867 non-null    float64
#  32  pooltypeid10                  464 non-null    float64
#  33  pooltypeid2                   1074 non-null   float64
#  34  pooltypeid7                   15042 non-null  float64
#  35  propertycountylandusecode     77380 non-null  object
#  36  propertylandusetypeid         77380 non-null  float64
#  37  propertyzoningdesc            50330 non-null  object
#  38  rawcensustractandblock        77380 non-null  float64
#  39  regionidcity                  75909 non-null  float64
#  40  regionidcounty                77380 non-null  float64
#  41  regionidneighborhood          30890 non-null  float64
#  42  regionidzip                   77330 non-null  float64
#  43  roomcnt                       77380 non-null  float64
#  44  threequarterbathnbr           10096 non-null  float64
#  45  unitcnt                       50562 non-null  float64
#  46  yardbuildingsqft17            2388 non-null   float64
#  47  yardbuildingsqft26            70 non-null     float64
#  48  yearbuilt                     77117 non-null  float64
#  49  numberofstories               17560 non-null  float64
#  50  fireplaceflag                 172 non-null    float64
#  51  structuretaxvaluedollarcnt    77268 non-null  float64
#  52  taxvaluedollarcnt             77379 non-null  float64
#  53  assessmentyear                77380 non-null  float64
#  54  landtaxvaluedollarcnt         77378 non-null  float64
#  55  taxamount                     77375 non-null  float64
#  56  taxdelinquencyflag            2886 non-null   object
#  57  taxdelinquencyyear            2886 non-null   float64
#  58  censustractandblock           77136 non-null  float64
#  59  logerror                      77413 non-null  float64
#  60  transactiondate               77413 non-null  object
#  61  airconditioningdesc           24953 non-null  object
#  62  architecturalstyledesc        206 non-null    object
#  63  buildingclassdesc             15 non-null     object
#  64  heatingorsystemdesc           49439 non-null  object
#  65  storydesc                     50 non-null     object
#  66  typeconstructiondesc          222 non-null    object
# dtypes: float64(55), int64(2), object(10)
# memory usage: 39.6+ MB

# %%
df.describe()
# Out:
#        typeconstructiontypeid          storytypeid  heatingorsystemtypeid  \
# count                  222.00                50.00              49,439.00
# mean                     6.04                 7.00                   3.92
# std                      0.56                 0.00                   3.59
# min                      4.00                 7.00                   1.00
# 25%                      6.00                 7.00                   2.00
# 50%                      6.00                 7.00                   2.00
# 75%                      6.00                 7.00                   7.00
# max                     13.00                 7.00                  24.00
#
#        buildingclasstypeid  architecturalstyletypeid  airconditioningtypeid  \
# count                15.00                    206.00              24,953.00
# mean                  3.93                      7.39                   1.81
# std                   0.26                      2.73                   2.97
# min                   3.00                      2.00                   1.00
# 25%                   4.00                      7.00                   1.00
# 50%                   4.00                      7.00                   1.00
# 75%                   4.00                      7.00                   1.00
# max                   4.00                     21.00                  13.00
#
#                   parcelid                   id         basementsqft  \
# count            77,413.00            77,413.00                50.00
# mean         13,006,697.32         1,495,761.15               679.72
# std           3,480,712.14           861,270.67               689.70
# min          10,711,855.00               349.00                38.00
# 25%          11,538,336.00           752,413.00               273.00
# 50%          12,530,673.00         1,498,471.00               515.00
# 75%          14,211,486.00         2,241,718.00               796.50
# max         167,689,317.00         2,985,182.00             3,560.00
#
#                bathroomcnt  ...      numberofstories        fireplaceflag  \
# count            77,380.00  ...            17,560.00               172.00
# mean                  2.30  ...                 1.43                 1.00
# std                   1.00  ...                 0.54                 0.00
# min                   0.00  ...                 1.00                 1.00
# 25%                   2.00  ...                 1.00                 1.00
# 50%                   2.00  ...                 1.00                 1.00
# 75%                   3.00  ...                 2.00                 1.00
# max                  18.00  ...                 6.00                 1.00
#
#        structuretaxvaluedollarcnt    taxvaluedollarcnt       assessmentyear  \
# count                   77,268.00            77,379.00            77,380.00
# mean                   189,315.98           490,137.46             2,016.00
# std                    230,088.56           653,447.67                 0.00
# min                         44.00             1,000.00             2,016.00
# 25%                     84,265.00           207,000.00             2,016.00
# 50%                    136,499.50           358,976.00             2,016.00
# 75%                    218,787.50           569,003.00             2,016.00
# max                 11,421,790.00        49,061,236.00             2,016.00
#
#        landtaxvaluedollarcnt            taxamount   taxdelinquencyyear  \
# count              77,378.00            77,375.00             2,886.00
# mean              301,096.94             5,995.57                14.09
# std               492,599.03             7,622.89                 2.19
# min                   161.00                19.92                 3.00
# 25%                85,504.00             2,715.59                14.00
# 50%               203,383.50             4,450.72                15.00
# 75%               366,802.25             6,927.80                15.00
# max            48,952,198.00           586,639.30                99.00
#
#          censustractandblock             logerror
# count              77,136.00            77,413.00
# mean   60,496,735,236,339.62                 0.02
# std     1,535,251,869,244.56                 0.17
# min    60,371,011,101,000.00                -4.66
# 25%    60,373,109,005,001.75                -0.02
# 50%    60,376,032,003,008.00                 0.01
# 75%    60,590,423,251,008.00                 0.04
# max   483,030,105,084,015.00                 5.26
#
# [8 rows x 57 columns]

# %%
df.isnull().sum()
# Out:
# typeconstructiontypeid          77191
# storytypeid                     77363
# heatingorsystemtypeid           27974
# buildingclasstypeid             77398
# architecturalstyletypeid        77207
# airconditioningtypeid           52460
# parcelid                            0
# id                                  0
# basementsqft                    77363
# bathroomcnt                        33
# bedroomcnt                         33
# buildingqualitytypeid           27742
# calculatedbathnbr                 642
# decktypeid                      76799
# finishedfloor1squarefeet        71390
# calculatedfinishedsquarefeet      229
# finishedsquarefeet12             3665
# finishedsquarefeet13            77372
# finishedsquarefeet15            74404
# finishedsquarefeet50            71390
# finishedsquarefeet6             77027
# fips                               33
# fireplacecnt                    69137
# fullbathcnt                       642
# garagecarcnt                    51939
# garagetotalsqft                 51939
# hashottuborspa                  75875
# latitude                           33
# longitude                          33
# lotsizesquarefeet                8272
# poolcnt                         61276
# poolsizesum                     76546
# pooltypeid10                    76949
# pooltypeid2                     76339
# pooltypeid7                     62371
# propertycountylandusecode          33
# propertylandusetypeid              33
# propertyzoningdesc              27083
# rawcensustractandblock             33
# regionidcity                     1504
# regionidcounty                     33
# regionidneighborhood            46523
# regionidzip                        83
# roomcnt                            33
# threequarterbathnbr             67317
# unitcnt                         26851
# yardbuildingsqft17              75025
# yardbuildingsqft26              77343
# yearbuilt                         296
# numberofstories                 59853
# fireplaceflag                   77241
# structuretaxvaluedollarcnt        145
# taxvaluedollarcnt                  34
# assessmentyear                     33
# landtaxvaluedollarcnt              35
# taxamount                          38
# taxdelinquencyflag              74527
# taxdelinquencyyear              74527
# censustractandblock               277
# logerror                            0
# transactiondate                     0
# airconditioningdesc             52460
# architecturalstyledesc          77207
# buildingclassdesc               77398
# heatingorsystemdesc             27974
# storydesc                       77363
# typeconstructiondesc            77191
# dtype: int64

# %%
from wrangle import clean_zillow

# %%
df = clean_zillow(df)

# %%
df.head()
# Out:
#           typeconstructiontypeid          storytypeid  heatingorsystemtypeid  \
# parcelid
# 10711855                     nan                  nan                   2.00
# 10711877                     nan                  nan                   2.00
# 10711888                     nan                  nan                   2.00
# 10711910                     nan                  nan                   2.00
# 10711923                     nan                  nan                   2.00
#
#           buildingclasstypeid  architecturalstyletypeid  \
# parcelid
# 10711855                  nan                       nan
# 10711877                  nan                       nan
# 10711888                  nan                       nan
# 10711910                  nan                       nan
# 10711923                  nan                       nan
#
#           airconditioningtypeid         basementsqft          bathroomcnt  \
# parcelid
# 10711855                   5.00                  nan                 2.00
# 10711877                   1.00                  nan                 2.00
# 10711888                   1.00                  nan                 2.00
# 10711910                   5.00                  nan                 2.00
# 10711923                   5.00                  nan                 2.00
#
#                    bedroomcnt           decktypeid  ...  \
# parcelid                                            ...
# 10711855                 3.00                  nan  ...
# 10711877                 4.00                  nan  ...
# 10711888                 4.00                  nan  ...
# 10711910                 3.00                  nan  ...
# 10711923                 4.00                  nan  ...
#
#           architecturalstyledesc  buildingclassdesc  heatingorsystemdesc  \
# parcelid
# 10711855                    None               None              Central
# 10711877                    None               None              Central
# 10711888                    None               None              Central
# 10711910                    None               None              Central
# 10711923                    None               None              Central
#
#           storydesc  typeconstructiondesc          age_of_home  \
# parcelid
# 10711855       None                  None                49.00
# 10711877       None                  None                49.00
# 10711888       None                  None                49.00
# 10711910       None                  None                61.00
# 10711923       None                  None                61.00
#
#                 bath_pers_qft  la_county  orange_county  ventura_county
# parcelid
# 10711855                 0.00          1              0               0
# 10711877                 0.00          1              0               0
# 10711888                 0.00          1              0               0
# 10711910                 0.00          1              0               0
# 10711923                 0.00          1              0               0
#
# [5 rows x 54 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (73201, 54)

# %%
df.describe()
# Out:
#        typeconstructiontypeid          storytypeid  heatingorsystemtypeid  \
# count                  222.00                50.00              73,201.00
# mean                     6.04                 7.00                   2.90
# std                      0.56                 0.00                   3.23
# min                      4.00                 7.00                   1.00
# 25%                      6.00                 7.00                   1.00
# 50%                      6.00                 7.00                   2.00
# 75%                      6.00                 7.00                   2.00
# max                     13.00                 7.00                  24.00
#
#        buildingclasstypeid  architecturalstyletypeid  airconditioningtypeid  \
# count                 0.00                    206.00              73,201.00
# mean                   nan                      7.39                   3.94
# std                    nan                      2.73                   2.28
# min                    nan                      2.00                   1.00
# 25%                    nan                      7.00                   1.00
# 50%                    nan                      7.00                   5.00
# 75%                    nan                      7.00                   5.00
# max                    nan                     21.00                  13.00
#
#               basementsqft          bathroomcnt           bedroomcnt  \
# count                50.00            73,201.00            73,201.00
# mean                679.72                 2.26                 3.01
# std                 689.70                 0.90                 0.99
# min                  38.00                 1.00                 1.00
# 25%                 273.00                 2.00                 2.00
# 50%                 515.00                 2.00                 3.00
# 75%                 796.50                 3.00                 4.00
# max               3,560.00                10.00                11.00
#
#                 decktypeid  ...        fireplaceflag    taxvaluedollarcnt  \
# count               597.00  ...            73,201.00            73,201.00
# mean                 66.00  ...                 0.11           450,886.36
# std                   0.00  ...                 0.32           390,297.09
# min                  66.00  ...                 0.00             1,000.00
# 25%                  66.00  ...                 0.00           205,718.00
# 50%                  66.00  ...                 0.00           355,700.00
# 75%                  66.00  ...                 0.00           560,000.00
# max                  66.00  ...                 1.00         2,999,902.00
#
#                  taxamount   taxdelinquencyyear             logerror  \
# count            73,201.00             2,609.00            73,201.00
# mean              5,533.01                14.10                 0.02
# std               4,563.09                 2.23                 0.16
# min                  19.92                 4.00                -4.66
# 25%               2,694.27                14.00                -0.02
# 50%               4,408.58                15.00                 0.01
# 75%               6,796.34                15.00                 0.04
# max              61,992.63                99.00                 3.39
#
#                age_of_home        bath_pers_qft            la_county  \
# count            73,201.00            73,201.00            73,201.00
# mean                 51.23                 0.00                 0.64
# std                  23.03                 0.00                 0.48
# min                   5.00                 0.00                 0.00
# 25%                  34.00                 0.00                 0.00
# 50%                  50.00                 0.00                 1.00
# 75%                  67.00                 0.00                 1.00
# max                 143.00                 0.01                 1.00
#
#              orange_county       ventura_county
# count            73,201.00            73,201.00
# mean                  0.27                 0.08
# std                   0.45                 0.28
# min                   0.00                 0.00
# 25%                   0.00                 0.00
# 50%                   0.00                 0.00
# 75%                   1.00                 0.00
# max                   1.00                 1.00
#
# [8 rows x 44 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73201 entries, 10711855 to 167688532
# Data columns (total 54 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   typeconstructiontypeid        222 non-null    float64
#  1   storytypeid                   50 non-null     float64
#  2   heatingorsystemtypeid         73201 non-null  float64
#  3   buildingclasstypeid           0 non-null      float64
#  4   architecturalstyletypeid      206 non-null    float64
#  5   airconditioningtypeid         73201 non-null  float64
#  6   basementsqft                  50 non-null     float64
#  7   bathroomcnt                   73201 non-null  float64
#  8   bedroomcnt                    73201 non-null  float64
#  9   decktypeid                    597 non-null    float64
#  10  finishedfloor1squarefeet      5976 non-null   float64
#  11  calculatedfinishedsquarefeet  73201 non-null  float64
#  12  finishedsquarefeet13          41 non-null     float64
#  13  finishedsquarefeet15          11 non-null     float64
#  14  finishedsquarefeet50          5976 non-null   float64
#  15  finishedsquarefeet6           158 non-null    float64
#  16  fips                          73201 non-null  object
#  17  fireplacecnt                  73201 non-null  float64
#  18  garagecarcnt                  25102 non-null  float64
#  19  garagetotalsqft               25102 non-null  float64
#  20  hashottuborspa                1463 non-null   float64
#  21  latitude                      73201 non-null  float64
#  22  longitude                     73201 non-null  float64
#  23  lotsizesquarefeet             73201 non-null  float64
#  24  poolcnt                       73201 non-null  float64
#  25  poolsizesum                   848 non-null    float64
#  26  pooltypeid10                  448 non-null    float64
#  27  pooltypeid2                   1015 non-null   float64
#  28  pooltypeid7                   14655 non-null  float64
#  29  regionidneighborhood          28629 non-null  float64
#  30  roomcnt                       73201 non-null  float64
#  31  threequarterbathnbr           9941 non-null   float64
#  32  yardbuildingsqft17            2361 non-null   float64
#  33  yardbuildingsqft26            67 non-null     float64
#  34  yearbuilt                     73201 non-null  object
#  35  numberofstories               17229 non-null  float64
#  36  fireplaceflag                 73201 non-null  int64
#  37  taxvaluedollarcnt             73201 non-null  float64
#  38  taxamount                     73201 non-null  float64
#  39  taxdelinquencyflag            2609 non-null   object
#  40  taxdelinquencyyear            2609 non-null   float64
#  41  logerror                      73201 non-null  float64
#  42  transactiondate               73201 non-null  datetime64[ns]
#  43  airconditioningdesc           73201 non-null  object
#  44  architecturalstyledesc        206 non-null    object
#  45  buildingclassdesc             0 non-null      object
#  46  heatingorsystemdesc           73201 non-null  object
#  47  storydesc                     50 non-null     object
#  48  typeconstructiondesc          222 non-null    object
#  49  age_of_home                   73201 non-null  float64
#  50  bath_pers_qft                 73201 non-null  float64
#  51  la_county                     73201 non-null  uint8
#  52  orange_county                 73201 non-null  uint8
#  53  ventura_county                73201 non-null  uint8
# dtypes: datetime64[ns](1), float64(40), int64(1), object(9), uint8(3)
# memory usage: 29.3+ MB

# %%
df.isnull().sum()
# Out:
# typeconstructiontypeid          72979
# storytypeid                     73151
# heatingorsystemtypeid               0
# buildingclasstypeid             73201
# architecturalstyletypeid        72995
# airconditioningtypeid               0
# basementsqft                    73151
# bathroomcnt                         0
# bedroomcnt                          0
# decktypeid                      72604
# finishedfloor1squarefeet        67225
# calculatedfinishedsquarefeet        0
# finishedsquarefeet13            73160
# finishedsquarefeet15            73190
# finishedsquarefeet50            67225
# finishedsquarefeet6             73043
# fips                                0
# fireplacecnt                        0
# garagecarcnt                    48099
# garagetotalsqft                 48099
# hashottuborspa                  71738
# latitude                            0
# longitude                           0
# lotsizesquarefeet                   0
# poolcnt                             0
# poolsizesum                     72353
# pooltypeid10                    72753
# pooltypeid2                     72186
# pooltypeid7                     58546
# regionidneighborhood            44572
# roomcnt                             0
# threequarterbathnbr             63260
# yardbuildingsqft17              70840
# yardbuildingsqft26              73134
# yearbuilt                           0
# numberofstories                 55972
# fireplaceflag                       0
# taxvaluedollarcnt                   0
# taxamount                           0
# taxdelinquencyflag              70592
# taxdelinquencyyear              70592
# logerror                            0
# transactiondate                     0
# airconditioningdesc                 0
# architecturalstyledesc          72995
# buildingclassdesc               73201
# heatingorsystemdesc                 0
# storydesc                       73151
# typeconstructiondesc            72979
# age_of_home                         0
# bath_pers_qft                       0
# la_county                           0
# orange_county                       0
# ventura_county                      0
# dtype: int64

# %%
from wrangle import missing_zero_values_table

# %%
missing_zero_values_table(df)
# Out:
# Your selected dataframe has 54 columns and 73201 Rows.
# There are 29 columns that have NULL values.
#                               Zero Values  null_count    % of Total Values  \
# buildingclasstypeid                     0       73201               100.00
# buildingclassdesc                       0       73201               100.00
# finishedsquarefeet15                    0       73190               100.00
# finishedsquarefeet13                    0       73160                99.90
# storydesc                               0       73151                99.90
# basementsqft                            0       73151                99.90
# storytypeid                             0       73151                99.90
# yardbuildingsqft26                      0       73134                99.90
# finishedsquarefeet6                     0       73043                99.80
# architecturalstyletypeid                0       72995                99.70
# architecturalstyledesc                  0       72995                99.70
# typeconstructiontypeid                  0       72979                99.70
# typeconstructiondesc                    0       72979                99.70
# pooltypeid10                            0       72753                99.40
# decktypeid                              0       72604                99.20
# poolsizesum                             0       72353                98.80
# pooltypeid2                             0       72186                98.60
# hashottuborspa                          0       71738                98.00
# yardbuildingsqft17                      0       70840                96.80
# taxdelinquencyyear                      0       70592                96.40
# taxdelinquencyflag                      0       70592                96.40
# finishedsquarefeet50                    0       67225                91.80
# finishedfloor1squarefeet                0       67225                91.80
# threequarterbathnbr                     0       63260                86.40
# pooltypeid7                             0       58546                80.00
# numberofstories                         0       55972                76.50
# garagecarcnt                           71       48099                65.70
# garagetotalsqft                      7500       48099                65.70
# regionidneighborhood                    0       44572                60.90
# heatingorsystemtypeid                   0           0                 0.00
# airconditioningtypeid                   0           0                 0.00
# age_of_home                             0           0                 0.00
# logerror                                0           0                 0.00
# heatingorsystemdesc                     0           0                 0.00
# bath_pers_qft                          65           0                 0.00
# la_county                           26202           0                 0.00
# orange_county                       53097           0                 0.00
# bathroomcnt                             0           0                 0.00
# bedroomcnt                              0           0                 0.00
# airconditioningdesc                     0           0                 0.00
# transactiondate                         0           0                 0.00
# fireplacecnt                        64823           0                 0.00
# taxamount                               0           0                 0.00
# taxvaluedollarcnt                       0           0                 0.00
# fireplaceflag                       64823           0                 0.00
# yearbuilt                               0           0                 0.00
# roomcnt                             55772           0                 0.00
# calculatedfinishedsquarefeet            0           0                 0.00
# fips                                    0           0                 0.00
# poolcnt                             57512           0                 0.00
# lotsizesquarefeet                       0           0                 0.00
# longitude                               0           0                 0.00
# latitude                                0           0                 0.00
# ventura_county                      67103           0                 0.00
#
#                               Total Zeroes + Null Values  \
# buildingclasstypeid                                73201
# buildingclassdesc                                  73201
# finishedsquarefeet15                               73190
# finishedsquarefeet13                               73160
# storydesc                                          73151
# basementsqft                                       73151
# storytypeid                                        73151
# yardbuildingsqft26                                 73134
# finishedsquarefeet6                                73043
# architecturalstyletypeid                           72995
# architecturalstyledesc                             72995
# typeconstructiontypeid                             72979
# typeconstructiondesc                               72979
# pooltypeid10                                       72753
# decktypeid                                         72604
# poolsizesum                                        72353
# pooltypeid2                                        72186
# hashottuborspa                                     71738
# yardbuildingsqft17                                 70840
# taxdelinquencyyear                                 70592
# taxdelinquencyflag                                 70592
# finishedsquarefeet50                               67225
# finishedfloor1squarefeet                           67225
# threequarterbathnbr                                63260
# pooltypeid7                                        58546
# numberofstories                                    55972
# garagecarcnt                                       48170
# garagetotalsqft                                    55599
# regionidneighborhood                               44572
# heatingorsystemtypeid                                  0
# airconditioningtypeid                                  0
# age_of_home                                            0
# logerror                                               0
# heatingorsystemdesc                                    0
# bath_pers_qft                                         65
# la_county                                          26202
# orange_county                                      53097
# bathroomcnt                                            0
# bedroomcnt                                             0
# airconditioningdesc                                    0
# transactiondate                                        0
# fireplacecnt                                       64823
# taxamount                                              0
# taxvaluedollarcnt                                      0
# fireplaceflag                                      64823
# yearbuilt                                              0
# roomcnt                                            55772
# calculatedfinishedsquarefeet                           0
# fips                                                   0
# poolcnt                                            57512
# lotsizesquarefeet                                      0
# longitude                                              0
# latitude                                               0
# ventura_county                                     67103
#
#                               % Total Zero + Null Values       Data Type
# buildingclasstypeid                               100.00         float64
# buildingclassdesc                                 100.00          object
# finishedsquarefeet15                              100.00         float64
# finishedsquarefeet13                               99.90         float64
# storydesc                                          99.90          object
# basementsqft                                       99.90         float64
# storytypeid                                        99.90         float64
# yardbuildingsqft26                                 99.90         float64
# finishedsquarefeet6                                99.80         float64
# architecturalstyletypeid                           99.70         float64
# architecturalstyledesc                             99.70          object
# typeconstructiontypeid                             99.70         float64
# typeconstructiondesc                               99.70          object
# pooltypeid10                                       99.40         float64
# decktypeid                                         99.20         float64
# poolsizesum                                        98.80         float64
# pooltypeid2                                        98.60         float64
# hashottuborspa                                     98.00         float64
# yardbuildingsqft17                                 96.80         float64
# taxdelinquencyyear                                 96.40         float64
# taxdelinquencyflag                                 96.40          object
# finishedsquarefeet50                               91.80         float64
# finishedfloor1squarefeet                           91.80         float64
# threequarterbathnbr                                86.40         float64
# pooltypeid7                                        80.00         float64
# numberofstories                                    76.50         float64
# garagecarcnt                                       65.80         float64
# garagetotalsqft                                    76.00         float64
# regionidneighborhood                               60.90         float64
# heatingorsystemtypeid                               0.00         float64
# airconditioningtypeid                               0.00         float64
# age_of_home                                         0.00         float64
# logerror                                            0.00         float64
# heatingorsystemdesc                                 0.00          object
# bath_pers_qft                                       0.10         float64
# la_county                                          35.80           uint8
# orange_county                                      72.50           uint8
# bathroomcnt                                         0.00         float64
# bedroomcnt                                          0.00         float64
# airconditioningdesc                                 0.00          object
# transactiondate                                     0.00  datetime64[ns]
# fireplacecnt                                       88.60         float64
# taxamount                                           0.00         float64
# taxvaluedollarcnt                                   0.00         float64
# fireplaceflag                                      88.60           int64
# yearbuilt                                           0.00          object
# roomcnt                                            76.20         float64
# calculatedfinishedsquarefeet                        0.00         float64
# fips                                                0.00          object
# poolcnt                                            78.60         float64
# lotsizesquarefeet                                   0.00         float64
# longitude                                           0.00         float64
# latitude                                            0.00         float64
# ventura_county                                     91.70           uint8

# %%
from wrangle import split

# %%
train, validate, test = split(df)

# %%
train. shape
# Out:
# (40992, 54)

# %%
validate.shape
# Out:
# (17568, 54)

# %%
test.shape
# Out:
# (14641, 54)

# %%
from wrangle import seperate_y

# %%
X_train, y_train, X_validate, y_validate, X_test, y_test = seperate_y(train, validate, test)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-9be99c732b3a> in <module>
# ----> 1 X_train, y_train, X_validate, y_validate, X_test, y_test = seperate_y(train, validate, test)
#
# ~/codeup-data-science/clustering-project/wrangle.py in seperate_y(train, validate, test)
#     221     own panda series
#     222     '''
# --> 223     X_train = train.drop(columns=['tax_value'])
#     224     y_train = train.tax_value
#     225     X_validate = validate.drop(columns=['tax_value'])
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3919                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3920             else:
# -> 3921                 new_axis = axis.drop(labels, errors=errors)
#    3922             result = self.reindex(**{axis_name: new_axis})
#    3923
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5280         if mask.any():
#    5281             if errors != "ignore":
# -> 5282                 raise KeyError(f"{labels[mask]} not found in axis")
#    5283             indexer = indexer[~mask]
#    5284         return self.delete(indexer)
#
# KeyError: "['tax_value'] not found in axis"

# %%
from wrangle import scale_data

# %%
train_scaled, validate_scaled, test_scaled = scale_data(train, validate, test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-b776c0b97e51> in <module>
# ----> 1 train_scaled, validate_scaled, test_scaled = scale_data(train, validate, test)
#
# ~/codeup-data-science/clustering-project/wrangle.py in scale_data(train, validate, test)
#     237     '''
#     238     # Make the thing
# --> 239     scaler = sklearn.preprocessing.MinMaxScaler()
#     240     # We fit on the training data
#     241     # we only .fit on the training data
#
# NameError: name 'sklearn' is not defined
